# %% [markdown]
# # Форматы данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Вывести телефоны, содержащиеся в адресной книге `addres-book.json`

# %%
import json
import pandas as pd
# from bs4 import BeautifulSoup
# import numpy as np
# import h5py
# from collections import Counter

# %%
fp = open(
    "addres-book.json",
    "r",
    encoding="utf-8"
)

# do smth

fp.close()

# %%
with open(
    "addres-book.json",
    "r",
    encoding="utf-8"
) as fp:
    # do smth 
    book = json.load(fp)
book
# Out:
# [{'name': 'Faina Lee',
#   'email': 'faina@mail.ru',
#   'birthday': '22.08.1994',
#   'phones': [{'phone': '232-19-55'}, {'phone': '+7 (916) 232-19-55'}]},
#  {'name': 'Robert Lee',
#   'email': 'robert@mail.ru',
#   'birthday': '22.08.1994',
#   'phones': [{'phone': '111-19-55'}, {'phone': '+7 (916) 445-19-55'}]}]

# %%
phones = []
for person in book:
    phones.extend(ph["phone"] for ph in person["phones"])
phones
# Out:
# ['232-19-55', '+7 (916) 232-19-55', '111-19-55', '+7 (916) 445-19-55']

# %% [markdown]
# 2. По данным из файла `addres-book-q.xml` сформировать список словарей с телефонами каждого из людей.

# %%
from bs4 import BeautifulSoup

with open(
    "addres-book-q.xml",
    "r",
    encoding="utf-8"
) as fp:
    # do smth 
    xml = BeautifulSoup(fp)

# %%
xml
# Out:
# <?xml version="1.0" encoding="UTF-8" ?><html><body><address_book>
# <country name="algeria">
# <address id="1">
# <gender>m</gender>
# <name>Aicha Barki</name>
# <email>aiqraa.asso@caramail.com</email>
# <position>Presidente</position>
# <company>Association Algerienne d'Alphabetisation Iqraa</company>
# <phones>
# <phone type="work">+ (213) 6150 4015</phone>
# <phone type="personal">+ (213) 2173 5247</phone>
# </phones>
# </address>
# </country>
# <country name="angola">
# <address id="2">
# <gender>m</gender>
# <name>Francisco Domingos</name>
# <email>frandomingos@hotmail.com</email>
# <position>Directeur General</position>
# <company>Institut National de Education des Adultes</company>
# <phones>
# <phone type="work">+ (244-2) 325 023</phone>
# <phone type="personal">+ (244-2) 325 023</phone>
# </phones>
# </address>
# <address id="3">
# <gender>f</gender>
# <name>Maria Luisa</name>
# <email>luisagrilo@ebonet.net</email>
# <position>Directrice Nationale</position>
# ...

# %%
address = xml.find_all("address")
type(address)
phones = address[0].find_all("phone")
# phones[0].text
phones[0].attrs, phones[0]["type"]
# Out:
# ({'type': 'work'}, 'work')

# %%
xml.find_all("address")[0].find_all("phone")[0]
# Out:
# <phone type="work">+ (213) 6150 4015</phone>

# %%
tg = xml.find_all("name")[0]
tg
# Out:
# <name>Aicha Barki</name>

# %%
phones[0].attrs

# %%
phones = []
addresses = xml.find_all("address")
for adress in addresses:
    phones.extend(ph.text for ph in adress.find_all('phone')
                  if ph["type"] == 'work')
phones
# Out:
# ['+ (213) 6150 4015',
#  '+ (244-2) 325 023',
#  '+ (244-2) 325 023',
#  '+ (54-11) 4784 1159',
#  '+ (61-2) 6274 9500',
#  '+ (61-3) 9807 4702']

# %% [markdown]
# 3. Создайте 2 матрицы размера 1000x1000, используя различные параметризируемые распределения из numpy (https://docs.scipy.org/doc/numpy-1.15.0/reference/routines.random.html#distributions)
#
# После этого сохраните получившиеся матрицы в hdf5-файл в виде двух различных датасетов. В качестве описания каждого датасета укажите параметры используемых распределений

# %%
import numpy as np
import h5py

m1 = np.random.exponential(scale=2, size=(1000, 1000))
m2 = np.random.exponential(scale=20, size=(1000, 1000))

with h5py.File(
    "test.h5",
    "w"
) as hdf:
    gr = hdf.create_group("group1") # создание группы
    exp1 = gr.create_dataset("exp1", data=m1) # добавится в группу
    exp1.attrs["description"] = 'Sample from exp. w scale 2'
    exp2 = hdf.create_dataset("exp2", data=m2) # не добавится в группу
    exp2.attrs["description"] = 'Sample from exp. w scale 20'
exp2
# Out:
# <Closed HDF5 dataset>

# %%
with h5py.File(
    "test.h5",
    "r"
) as hdf:
    print(hdf.keys())
    # exp1 = hdf["exp1"]
    # print(exp1)
    # data = exp1[:100, :100]

# print(data)
# print(exp1[100:200, 100:200]) вызывает ошибку так как "закрытый датасет"
# exp1 # закрытый датасет
# Out:
# <KeysViewHDF5 ['exp2', 'group1']>

# %% [markdown]
# ## Лабораторная работа №3

# %%
import h5py
import json
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from collections import Counter

# %% [markdown]
# ### JSON

# %% [markdown]
# 1.1 Считайте файл `contributors_sample.json`, воспользовавшись модулем `json` и свяжите загруженные данные с переменной `contributors`. Выведите на экран уникальные почтовые домены, содержащиеся в почтовых адресах людей. Под доменом понимается часть адреса, следующая за символом `@`.

# %%
with open(
    "contributors_sample.json",
    "r",
    encoding="utf-8"
) as fp:
    # do smth 
    contributors = json.load(fp)
contributors
# Out:
# [{'username': 'uhebert',
#   'name': 'Lindsey Nguyen',
#   'sex': 'F',
#   'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#   'mail': 'jsalazar@gmail.com',
#   'jobs': ['Energy engineer',
#    'Engineer, site',
#    'Environmental health practitioner',
#    'Biomedical scientist',
#    'Jewellery designer'],
#   'id': 35193},
#  {'username': 'vickitaylor',
#   'name': 'Cheryl Lewis',
#   'sex': 'F',
#   'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#   'mail': 'bhudson@gmail.com',
#   'jobs': ['Music therapist',
#    'Volunteer coordinator',
#    'Designer, interior/spatial'],
#   'id': 91970},
#  {'username': 'sheilaadams',
#   'name': 'Julia Allen',
#   'sex': 'F',
#   'address': 'Unit 1632 Box 2971\nDPO AE 23297',
#   'mail': 'darren44@yahoo.com',
#   'jobs': ['Management consultant',
#    'Engineer, structural',
#    'Lecturer, higher education',
#    'Theatre manager',
#    'Designer, textile'],
#   'id': 1848091},
#  {'username': 'nicole82',
# ...

# %%
domain = []
for person in contributors:
    domain.append(person["mail"].rpartition('@')[2])

print(set(domain))
# Out:
# {'gmail.com', 'yahoo.com', 'hotmail.com'}

# %% [markdown]
# 1.2 Посчитайте, как часто встречается та или иная должность во всем наборе данных. Выведите на экран 5 должностей, которые встречаются наиболее часто. Для каждого пользователя из `contributors` выясните, какая из его должностей является наиболее распространенной (в смысле частоты упоминания во всем датасете) и добавьте ключ `top_job`, в котором хранится название этой должности.

# %%
lst_jobs = []
for person in contributors:
    lst_jobs.extend(person["jobs"])
    
dict_with_jobs = dict(sorted(Counter(lst_jobs).items(), key = lambda x: x[1], reverse = True))
dict_with_jobs
# Out:
# {'Chemical engineer': 42,
#  'Chief Operating Officer': 41,
#  'Dance movement psychotherapist': 41,
#  'Bookseller': 41,
#  'Telecommunications researcher': 41,
#  'Restaurant manager, fast food': 40,
#  'Pilot, airline': 40,
#  'Seismic interpreter': 39,
#  'Television production assistant': 39,
#  'Trade mark attorney': 38,
#  'Clinical cytogeneticist': 38,
#  'Education administrator': 37,
#  'Counsellor': 37,
#  'Commercial/residential surveyor': 37,
#  'Magazine features editor': 37,
#  'Firefighter': 36,
#  'Programmer, multimedia': 36,
#  'Water engineer': 36,
#  'Librarian, academic': 36,
#  'Energy manager': 36,
#  'Librarian, public': 36,
#  'Aeronautical engineer': 36,
#  'Research officer, government': 36,
#  'Educational psychologist': 36,
#  'Claims inspector/assessor': 36,
#  'Barrister': 35,
#  'Publishing rights manager': 35,
#  'Engineer, civil (consulting)': 35,
#  'Designer, exhibition/display': 35,
#  'Lexicographer': 35,
#  'Engineer, water': 35,
# ...

# %%
uniq, counts = np.unique(lst_jobs, return_counts=True)
print("Уникальные элементы и количество их вхождений: ", "\n", np.asarray((uniq, counts)).T)
# Out:
# Уникальные элементы и количество их вхождений:
#  [['Academic librarian' '18']
#  ['Accommodation manager' '24']
#  ['Accountant, chartered' '30']
#  ...
#  ['Wellsite geologist' '21']
#  ['Writer' '19']
#  ['Youth worker' '33']]

# %%
five_most_frec = np.argsort(counts)[-5:]
print(uniq[five_most_frec])
# Out:
# ['Bookseller' 'Telecommunications researcher' 'Chief Operating Officer'
#  'Dance movement psychotherapist' 'Chemical engineer']

# %%
for person in contributors:
    pers_jobs = [dict_with_jobs[pers] for pers in person["jobs"]]
    person['top_job'] = person['jobs'][np.argmax(pers_jobs)]
    
contributors
# Out:
# [{'username': 'uhebert',
#   'name': 'Lindsey Nguyen',
#   'sex': 'F',
#   'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#   'mail': 'jsalazar@gmail.com',
#   'jobs': ['Energy engineer',
#    'Engineer, site',
#    'Environmental health practitioner',
#    'Biomedical scientist',
#    'Jewellery designer'],
#   'id': 35193,
#   'top_job': 'Environmental health practitioner'},
#  {'username': 'vickitaylor',
#   'name': 'Cheryl Lewis',
#   'sex': 'F',
#   'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#   'mail': 'bhudson@gmail.com',
#   'jobs': ['Music therapist',
#    'Volunteer coordinator',
#    'Designer, interior/spatial'],
#   'id': 91970,
#   'top_job': 'Music therapist'},
#  {'username': 'sheilaadams',
#   'name': 'Julia Allen',
#   'sex': 'F',
#   'address': 'Unit 1632 Box 2971\nDPO AE 23297',
#   'mail': 'darren44@yahoo.com',
#   'jobs': ['Management consultant',
#    'Engineer, structural',
#    'Lecturer, higher education',
#    'Theatre manager',
# ...

# %% [markdown]
# 1.3 Создайте `pd.DataFrame` `contributors_df`, имеющий столбцы `id`, `username` и `sex` и `n_jobs`. Столбец `n_jobs` содержит кол-во должностей пользователя. При необходимости вы можете преобразовать исходные данные в списке `contributors` в удобный для создания `pd.DataFrame` вид.
#
# Сгруппируйте полученные данные по столбцам `n_jobs` и `sex`. Выведите на экран серию `pd.Series`, в которой содержится информация о количестве человек в каждой группе.

# %%
[contributors[dct].update({'jobs': len(contributors[dct].get('jobs'))}) for dct in range(len(contributors))]
contributors
# Out:
# [{'username': 'uhebert',
#   'name': 'Lindsey Nguyen',
#   'sex': 'F',
#   'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#   'mail': 'jsalazar@gmail.com',
#   'jobs': 5,
#   'id': 35193,
#   'top_job': 'Environmental health practitioner'},
#  {'username': 'vickitaylor',
#   'name': 'Cheryl Lewis',
#   'sex': 'F',
#   'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#   'mail': 'bhudson@gmail.com',
#   'jobs': 3,
#   'id': 91970,
#   'top_job': 'Music therapist'},
#  {'username': 'sheilaadams',
#   'name': 'Julia Allen',
#   'sex': 'F',
#   'address': 'Unit 1632 Box 2971\nDPO AE 23297',
#   'mail': 'darren44@yahoo.com',
#   'jobs': 5,
#   'id': 1848091,
#   'top_job': 'Management consultant'},
#  {'username': 'nicole82',
#   'name': 'Gina Stevens',
#   'sex': 'F',
#   'address': '9880 Michelle Bridge\nNew Kimberlybury, WY 02583',
#   'mail': 'stevensonsarah@hotmail.com',
#   'jobs': 3,
#   'id': 50969,
#   'top_job': 'Barrister'},
#  {'username': 'jean67',
# ...

# %%
contributors_df = pd.DataFrame.from_dict(contributors)
contributors_df = contributors_df.rename(columns={"jobs": "n_jobs"})
contributors_df
# Out:
#            username                 name sex  \
# 0           uhebert       Lindsey Nguyen   F
# 1       vickitaylor         Cheryl Lewis   F
# 2       sheilaadams          Julia Allen   F
# 3          nicole82         Gina Stevens   F
# 4            jean67  Nicholas Harrington   M
# ...             ...                  ...  ..
# 4195  stevenspencer         Pamela Moore   F
# 4196      rwilliams    Benjamin Campbell   M
# 4197      lmartinez     Jennifer Johnson   F
# 4198     brendahill      Nicholas Hansen   M
# 4199       mistyray       Sandra Johnson   F
#
#                                                 address  \
# 0            01261 Cameron Spring\nTaylorfurt, AK 97791
# 1           66992 Welch Brooks\nMarshallshire, ID 56004
# 2                      Unit 1632 Box 2971\nDPO AE 23297
# 3      9880 Michelle Bridge\nNew Kimberlybury, WY 02583
# 4     9080 Monica Crescent Suite 820\nNorth Deanbury...
# ...                                                 ...
# ...

# %%
grouped = contributors_df.groupby(["sex", "n_jobs"])["id"].count()
grouped
# Out:
# sex  n_jobs
# F    3         703
#      4         733
#      5         700
# M    3         690
#      4         704
#      5         670
# Name: id, dtype: int64

# %% [markdown]
# ### XML

# %% [markdown]
# 2.1 По данным файла `steps_sample.xml` сформируйте словарь с шагами по каждому рецепту вида `{id_рецепта: ["шаг1", "шаг2"]}`. Сохраните этот словарь в файл `steps_sample.json`. Выведите на экран шаги рецепта с id `84797`.

# %%
from bs4 import BeautifulSoup

with open(
    "steps_sample.xml",
    "r",
    encoding="utf-8"
) as fp:
    xml = BeautifulSoup(fp)

# %%
steps_for_recipes = {}
recipes = xml.find_all("recipe")
for recip in recipes:
    steps_for_recipes.update({int(recip.find("id").get_text()):[st.text for st in recip.find_all("step")]})

steps_for_recipes
# Out:
# {44123: ['in 1 / 4 cup butter , saute carrots , onion , celery and broccoli stems for 5 minutes',
#   'add thyme , oregano and basil',
#   'saute 5 minutes more',
#   'add wine and deglaze pan',
#   'add hot chicken stock and reduce by one-third',
#   'add worcestershire sauce , tabasco , smoked chicken , beans and broccoli florets',
#   'simmer 5 minutes',
#   'add cream , simmer 5 minutes more and season to taste',
#   'drop in remaining butter , piece by piece , stirring until melted and serve immediately',
#   'smoked chicken: on a covered grill , slightly smoke boneless chicken , cooking to medium rare',
#   'chef meskan uses applewood chips and does not allow the grill to become too hot'],
#  67664: ['mix all the ingredients using a blender',
#   'pour into popsicle molds',
#   'freeze and enjoy !'],
#  38798: ['combine all ingredients in a large bowl and mix well',
#   'shape into one-inch balls',
#   'cover and refrigerate or freeze until ready to bake',
# ...

# %%
steps_for_recipes[84797]
# Out:
# ['honey mustard sauce: whisk all the ingredients together serve warm or cold',
#  'easy bbq sauce: combine all ingredients in a pot& cook over low heat until the sugar is dissolved',
#  'serve warm or cold',
#  'garlic dill sauce: mix all the ingredients and chill until ready to serve']

# %%
with open(
    "steps_sample.json",
    "w",
    encoding="utf-8"
) as f:
    json.dump(steps_for_recipes, f)

# %% [markdown]
# 2.2 Получите список идентификаторов рецептов, в этапах выполнения которых есть информация о времени (часы или минуты). Для отбора подходящих рецептов обратите внимание на атрибуты соответствующих тэгов. Выведите на экран количество таких рецептов.

# %%
identificators = []
recipes = xml.find_all("recipe")
for recip in recipes:
    recipe_id = int(recip.find("id").get_text())
    for recip in recip.find_all("step"):
        if recip.has_attr('has_hours') or recip.has_attr('has_minutes'):
            identificators.append(recipe_id)

print(len(set(identificators)))
print("\n")
print(set(identificators))
# Out:
# 23469
#
#
# ...

# %% [markdown]
# 2.3 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Для строк, которые содержат пропуски в столбце `n_steps`, заполните этот столбец на основе файла  `steps_sample.xml`. Строки, в которых столбец `n_steps` заполнен, оставьте без изменений. При решении задачи не используйте метод `iterrows` и аналогичные ему, позволяющие итерироваться по таблице построчно.
#
# Проверьте, содержит ли столбец `n_steps` пропуски. Если нет, то преобразуйте его к целочисленному типу и сохраните результаты в файл `recipes_sample_with_filled_nsteps.csv`

# %%
recipes_df = pd.read_csv("recipes_sample.csv", index_col=1)
recipes_df
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 44123          george s at the cove  black bean soup       90           35193
# 67664             healthy for them  yogurt popsicles       10           91970
# 38798                   i can t believe it s spinach       30            1533
# 35173                           italian  gut busters       45           22724
# 84797       love is in the air  beef fondue   sauces       25            4470
# ...                                              ...      ...             ...
# 267661  zurie s holey rustic olive and cheddar bread       80          200862
# 386977          zwetschgenkuchen  bavarian plum cake      240          177443
# 103312   zwiebelkuchen   southwest german onion cake       75          161745
# 486161                                   zydeco soup       60          227978
# 298512        cookies by design   cookies on a stick       29          506822
#
# ...

# %%
amount_of_steps_for_recipes = {}
recipes = xml.find_all("recipe")
for recip in recipes:
    amount_of_steps_for_recipes.update({int(recip.find("id").get_text()):len([st.text for st in recip.find_all("step")])})

amount_of_steps_for_recipes
# Out:
# {44123: 11,
#  67664: 3,
#  38798: 5,
#  35173: 7,
#  84797: 4,
#  44045: 6,
#  107229: 8,
#  95926: 4,
#  453467: 12,
#  306168: 6,
#  50662: 15,
#  118843: 3,
#  69190: 5,
#  503475: 10,
#  149593: 10,
#  200148: 18,
#  310570: 38,
#  95534: 10,
#  109818: 7,
#  66932: 7,
#  226001: 12,
#  125195: 5,
#  141939: 13,
#  250883: 14,
#  120297: 14,
#  147477: 3,
#  223349: 7,
#  60938: 10,
#  302399: 11,
#  342620: 9,
#  296983: 14,
#  166089: 14,
#  129581: 33,
#  116741: 2,
#  325714: 6,
#  276594: 6,
#  487173: 30,
#  289671: 6,
#  44050: 2,
#  447429: 24,
#  137701: 18,
#  292568: 2,
#  299989: 14,
#  63346: 7,
#  342619: 9,
#  383120: 10,
#  367987: 3,
#  463219: 8,
#  39172: 8,
#  216068: 3,
#  173730: 28,
#  287778: 9,
#  437637: 10,
#  123115: 14,
#  371549: 8,
#  376813: 9,
#  134085: 4,
#  390230: 34,
#  401605: 7,
#  306590: 5,
#  303944: 13,
#  299968: 13,
#  192542: 4,
#  147563: 9,
#  193719: 16,
#  38852: 9,
#  250232: 10,
#  134787: 7,
#  437219: 9,
#  77380: 5,
# ...

# %%
recipes_df["n_steps"] = recipes_df["n_steps"].fillna(value=amount_of_steps_for_recipes, axis=0)
recipes_df
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 44123          george s at the cove  black bean soup       90           35193
# 67664             healthy for them  yogurt popsicles       10           91970
# 38798                   i can t believe it s spinach       30            1533
# 35173                           italian  gut busters       45           22724
# 84797       love is in the air  beef fondue   sauces       25            4470
# ...                                              ...      ...             ...
# 267661  zurie s holey rustic olive and cheddar bread       80          200862
# 386977          zwetschgenkuchen  bavarian plum cake      240          177443
# 103312   zwiebelkuchen   southwest german onion cake       75          161745
# 486161                                   zydeco soup       60          227978
# 298512        cookies by design   cookies on a stick       29          506822
#
# ...

# %%
recipes_df.isnull().any()
# Out:
# name              False
# minutes           False
# contributor_id    False
# submitted         False
# n_steps           False
# description        True
# n_ingredients      True
# dtype: bool

# %%
recipes_df = recipes_df.astype({'n_steps':'int'})
recipes_df
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 44123          george s at the cove  black bean soup       90           35193
# 67664             healthy for them  yogurt popsicles       10           91970
# 38798                   i can t believe it s spinach       30            1533
# 35173                           italian  gut busters       45           22724
# 84797       love is in the air  beef fondue   sauces       25            4470
# ...                                              ...      ...             ...
# 267661  zurie s holey rustic olive and cheddar bread       80          200862
# 386977          zwetschgenkuchen  bavarian plum cake      240          177443
# 103312   zwiebelkuchen   southwest german onion cake       75          161745
# 486161                                   zydeco soup       60          227978
# 298512        cookies by design   cookies on a stick       29          506822
#
# ...

# %%
recipes_df.to_csv('recipes_sample_with_filled_nsteps.csv')

# %% [markdown]
# ### hdf

# %% [markdown]
# 3.1 Выведите названия всех датасетов, находящихся в файле `nutrition_sample.h5`, а также размерность матриц, содержащихся в данных датасетах и их метаданные.
#
# Формат вывода:
# ```
# Dataset name=dataset_0 n_rows=30000 n_cols=2 col_0=recipe_id col_1=calories (#)
# Dataset name=dataset_1 n_rows=30000 n_cols=2 col_0=recipe_id col_1=total fat (PDV)
# Dataset name=dataset_2 n_rows=30000 n_cols=2 col_0=recipe_id col_1=sugar (PDV)
# ...
# ```

# %%
datasets_dict = {}
with h5py.File(
    "nutrition_sample.h5",
    "r"
) as hdf:
    for key in hdf.keys():
        file = hdf[key]
        metadata = dict(file.attrs)
        print(f"Dataset name={key}, dataset size={file.shape}, metadata={metadata}")
        datasets_dict[key] = {"all" : {'data': file[:]}, 'attrs': metadata}
# Out:
# Dataset name=dataset_0, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'calories (#)'}
# Dataset name=dataset_1, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'total fat (PDV)'}
# Dataset name=dataset_2, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'sugar (PDV)'}
# Dataset name=dataset_3, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'sodium (PDV)'}
# Dataset name=dataset_4, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'protein (PDV)'}
# Dataset name=dataset_5, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'saturated fat (PDV)'}
# Dataset name=dataset_6, dataset size=(30000, 2), metadata={'col_0': 'recipe_id', 'col_1': 'carbohydrates (PDV)'}

# %%
datasets_dict
# Out:
# {'dataset_0': {'all': {'data': array([[4.41230e+04, 8.04700e+02],
#           [6.76640e+04, 1.64600e+02],
#           [3.87980e+04, 5.38000e+01],
#           ...,
#           [1.03312e+05, 8.64100e+02],
#           [4.86161e+05, 4.15200e+02],
#           [2.98512e+05, 1.88000e+02]])},
#   'attrs': {'col_0': 'recipe_id', 'col_1': 'calories (#)'}},
#  'dataset_1': {'all': {'data': array([[4.41230e+04, 1.08000e+02],
#           [6.76640e+04, 3.00000e+00],
#           [3.87980e+04, 5.00000e+00],
#           ...,
#           [1.03312e+05, 8.70000e+01],
#           [4.86161e+05, 2.60000e+01],
#           [2.98512e+05, 1.10000e+01]])},
#   'attrs': {'col_0': 'recipe_id', 'col_1': 'total fat (PDV)'}},
#  'dataset_2': {'all': {'data': array([[4.41230e+04, 2.60000e+01],
#           [6.76640e+04, 5.00000e+00],
#           [3.87980e+04, 2.00000e+00],
#           ...,
#           [1.03312e+05, 3.00000e+01],
#           [4.86161e+05, 3.40000e+01],
#           [2.98512e+05, 5.70000e+01]])},
# ...
